# %% [markdown]
# <a href="https://colab.research.google.com/github/spoilypippip/calcee/blob/main/%E0%B8%99%E0%B8%B1%E0%B8%9A%E0%B8%82%E0%B8%B5%E0%B9%89%E0%B8%A5%E0%B9%88%E0%B8%B2%E0%B8%AA%E0%B8%B8%E0%B8%94%E0%B8%97%E0%B8%B5%E0%B9%88%E0%B8%AA%E0%B8%B8%E0%B8%94%E0%B9%81%E0%B8%A5%E0%B9%89%E0%B8%A7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/นับขี้
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11s.pt")

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/rabbitfeces2.v7i.yolov11รวม/data.yaml",  # path to dataset YAML
    epochs=200,  # number of training epochs
    imgsz=640,  # training image size
    device="0",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)

# Evaluate model performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("/content/drive/MyDrive/testimg/IMG_8568.jpg")
results[0].show()

# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
# Out:
# Ultralytics 8.3.76 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/นับขี้/runs/detect/train5/weights/best.pt")
results = model("/content/drive/MyDrive/รูปอึ/ขี้กระต่าย/L8 เล็ก.jpg")
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/รูปอึ/ขี้กระต่าย/L8 เล็ก.jpg: 640x288 13 normals, 5 small-misshapens, 47.4ms
# Speed: 12.2ms preprocess, 47.4ms inference, 324.5ms postprocess per image at shape (1, 3, 640, 288)
# <PIL.Image.Image image mode=RGB size=572x1280>

# %%
# !pip install onnx2tf
# !pip install onnx
# !pip install onnx_graphsurgeon
# !pip install sng4onnx
# !pip install onnxruntime-gpu
# !pip install tflite_support
# !pip install protobuf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 22.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("/content/drive/MyDrive/best.pt")

# Export the model to TFLite format
model.export(format="tflite")  # creates 'yolo11n_float32.tflite'

# Load the exported TFLite model
tflite_model = YOLO("/content/drive/MyDrive/นับขี้/runs/detect/train5/weights/best_saved_model/best_float32.tflite")

# Run inference
results = tflite_model("/content/drive/MyDrive/testimg/test.jpg")
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11s summary (fused): 100 layers, 9,415,896 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (18.3 MB)
# requirements: Ultralytics requirements ['onnx2tf>1.17.5,<=1.26.3', 'onnxruntime', 'protobuf>=5'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.6/445.6 kB 211.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 240.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 340.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
# ...

# %%
# Load the exported TFLite model
tflite_model = YOLO("/content/drive/MyDrive/best_saved_model/best_float32.tflite")

# Run inference
results = tflite_model("/content/drive/MyDrive/testimg/test.jpg")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /content/drive/MyDrive/best_saved_model/best_float32.tflite for TensorFlow Lite inference...
#
# image 1/1 /content/drive/MyDrive/testimg/test.jpg: 640x640 11 Small Misshapens, 6 normals, 532.3ms
# Speed: 11.5ms preprocess, 532.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
